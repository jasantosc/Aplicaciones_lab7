# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("movies.xlsx")

# %%
df.duplicated().sum()
# Out:
# np.int64(112)

# %%
df.isna().sum()
# Out:
# MOVIES        0
# YEAR         66
# GENRE         4
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RunTime     311
# Gross       959
# dtype: int64

# %%
df.STARS.iloc[3].split("|")[0].replace("Director", "").strip()
df.STARS.iloc[3].split("|")[1].replace("Stars", "").replace("\n", "").strip()
