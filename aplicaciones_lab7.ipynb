# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("movies.xlsx")
df.head()
# Out:
#                                               MOVIES               YEAR  \
# 0                   PokÃ©mon: Happy Birthday to You!  (2017 TV Special)
# 1                  Beat Bugs: Happy Birthday to You!  (2017 TV Special)
# 2               Project McÂ²: Happy Birthday to You!  (2017 TV Special)
# 3                              The Sense8 Experience             (2017)
# 4  Night of 1000 Meryls: Drag Queens Perform Mery...       (2020 Video)
#
#                                 GENRE  RATING  \
# 0      \nAnimation, Short                 5.4
# 1      \nAnimation, Short                 0.0
# 2                 \nShort                 0.0
# 3                 \nShort                 8.9
# 4  \nShort, Comedy, Music                 0.0
#
#                                             ONE-LINE  \
# 0  \nToday is your big day, and Ash, Pikachu and ...
# 1  \nThey say it's your birthday - and there's no...
# 2  \nMcKeyla and the agents of NOV8 have chosen y...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(112)

# %%
df.isna().sum()
# Out:
# MOVIES        0
# YEAR         66
# GENRE         4
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RunTime     311
# Gross       959
# dtype: int64

# %%
Director = df.STARS.iloc[3].split("|")[0].replace("Director", "").strip()
Stars = df.STARS.iloc[3].split("|")[1].replace("Stars", "").replace("\n", "").strip()

# %%
def extraer_director(stars_str):
    if "Director" in stars_str:
        clean_str = stars_str.split("|")[0].replace("Director", "").replace("\n", "").strip()
    else:
        return np.nan

# %%
df["DIRECTOR"] = df["STARS"].apply(extraer_director)

# %%
def extraer_reparto(stars_str):
    if "STAR" in stars_str or "STARS" in stars_str:
        clean_str = stars_str.split("|")[1].replace("STAR", "").replace("STARS", "").replace("\n", "").strip()
    else:
        return np.nan

# %%
df["STAR"] = df["STARS"].apply(extraer_reparto)

# %% [markdown]
# Punto 4.

# %%
df["MOVIES"] = df["MOVIES"].str.strip()

print("Nulos en RunTime: ", df["RunTime"].isnull().sum())

rt = df["RunTime"]
a = rt.dropna()
b = rt.fillna(rt.mean())
c = rt.fillna(rt.median())

comparacion = pd.DataFrame({
    "num": [a.count(), b.count(), c.count()],
    "media": [a.mean(), b.mean(), c.mean()],
    "mediana": [a.median(), b.median(), c.median()],
    "std": [a.std(), b.std(), c.std()]
}, index=["Borrar", "Media", "Mediana"]).round(2)

print(comparacion)

print("Asimetría: ", rt.skew().round(2))
print("Rating promedio (todo): ", df["Rating"].mean().round(2))
print("Rating promedio (sin nulos): ", round(df.notna()["Rating"].mean(), 2))
print("% de nulos en Rating = 0: ", round(df.loc[rt.isna, "Rating"].eq(0).mean() * 100, 1))

df["RunTime"] = df["RunTime"].fillna(rt.median())
# Out:
# Nulos en RunTime:  311
#           num   media  mediana     std
# Borrar    689  689.58   600.00  455.22
# Media    1000  689.58   689.58  377.77
# Mediana  1000  661.72   600.00  380.04
# Asimetría:  3.28
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
